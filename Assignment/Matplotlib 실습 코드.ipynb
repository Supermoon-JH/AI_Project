# %%
import matplotlib
import matplotlib.pyplot as plt
# %command : jupyter notebook의 magic command
# %matplotlib nbagg : matplotlib 을 jupyter notebook에서 plot의 이미지를 보여주기 위해 설정
# %matplotlib nbagg
import numpy as np
import pandas as pd

# %%
# 1. Plot 개요

# %%
# 1.1 plot 생성 및 그리기 예
# fig : figure 객체, ax : axes 객체
fig, ax = plt.subplots()  # Create a figure containing a single axes.
# [1, 2, 3, 4], [1, 4, 2, 3] => numpy array data type
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.

# %%
# 1.2 fig 생성방법 3가지 예
fig = plt.figure()  # an empty figure with no Axes

# %%
fig, ax = plt.subplots()  # a figure with a single Axes

# %%
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
# ax1 = plt.subplots(2, 2, 1)
# ax2 = plt.subplots(2, 2, 2)
# ax3 = plt.subplots(2, 2, 3)
# ax4 = plt.subplots(2, 2, 4)

# %%
# 1.3 input data type을 numpy Array로 변환하는 방법

# pandas.DataFrame 객체 => numpy Array로 변환
a = pd.DataFrame(np.random.rand(4, 5), columns = list('abcde'))
a_asarray = a.values
# numpy.matrix 객체 => numpy Array로 변환
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)

# %%
# 1.4 Matplotlib를 이용한 plot 그리기 2가지 방법

# 1) object-oriented interface (fig, axes)를 통해 plot 그리기
# linspace(start, end, number) => start값과 end 값 사이에 number갯수를 만들라는 의미
# np.linspace(0, 2, 100) => 0과 2사이에 100개의 숫자를 만들라는 의미
x = np.linspace(0, 2, 100)
# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
# 2) pyplot interface (plot함수 사용)를 통해 plot 그리기
# => Jupyter notebook에서 추천하는 방식

x = np.linspace(0, 2, 100)
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
# 1.5 plot 그리기 함수를 library화하여 사용하는 방법
# my_plotter 함수 선언
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph

    Parameters
    ----------
    ax : Axes
        The axes to draw to

    data1 : array
       The x data

    data2 : array
       The y data

    param_dict : dict
       Dictionary of kwargs to pass to ax.plot

    Returns
    -------
    out : list
        list of artists added
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# my_plotter 함수 사용 예 1
# np.random.randn(4, 100) => 4*100 2차원 data
# data1, data2, data3, data4 => 각각 1*100 데이터 가짐
data1, data2, data3, data4 = np.random.randn(4, 100)
# subplots(a, b) => a : axes의 행의 갯수, b: axes의 열의 갯수
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {'marker': 'x'})

# %%
# my_plotter 함수 사용 예 2
# one plot 객체, 2개의 axes객체를 갖고 있음
fig, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})

# %%
# 2. plot graph 종류

# %%
# 2.1 Line plot 그리기

# %%
# 예제 1. Series를 통한 line plot 그리기 예제 1
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
print(s)
s.plot()
# Out:
# 0    -0.954188
# 10    0.749515
# 20   -0.364003
# 30    0.667214
# 40    1.743601
# 50    3.228821
# 60    2.692545
# 70    3.667652
# 80    5.399060
# 90    8.262278
# dtype: float64

# %%
# 예제 2. DataFrame을 통한 line plot 그리기
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
print(df)
df.plot()
# Out:
#            A         B         C         D
# 0  -2.196717 -0.834086 -0.424848 -0.637305
# 10 -1.229090 -1.890531  2.402195 -1.682586
# 20 -0.618764 -0.946247  4.560133 -3.156058
# 30 -1.713634 -0.016206  4.027497 -2.574964
# 40 -1.236363  0.797360  4.845607 -3.238646
# 50 -1.279333  2.771420  4.566185 -5.111755
# 60  0.124932  3.319260  3.669282 -3.591163
# 70 -0.894882  3.446643  2.688718 -4.179068
# 80  0.738242  3.678393  1.841861 -5.173581
# 90 -1.081651  3.816751  1.562834 -3.536955

# %%
# 하나의 열에 대해서만 line plot 그리기
df['B'].plot()

# %%
# 2.2. Bar plot 그리기
s2 = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))
print(s2)
# Out:
# a    0.644373
# b    0.544987
# c    0.577002
# d    0.497729
# e    0.353379
# f    0.507599
# g    0.368193
# h    0.711453
# i    0.724891
# j    0.830251
# k    0.354545
# l    0.929078
# m    0.824105
# n    0.164950
# o    0.914545
# p    0.704962
# dtype: float64

# %%
# 세로방향의 bar plot그리기
s2.plot(kind='bar')

# %%
# 가로방향의 bar plot그리기
# barh의 h (horizontal)
s2.plot(kind='barh')

# %%
# DataFrame을 이용한 bar plot그리기
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Genus"))
print(df2)
df2.plot(kind='bar')
# Out:
# Genus         A         B         C         D
# one    0.325497  0.728403  0.775460  0.744353
# two    0.604267  0.263670  0.409452  0.110277
# three  0.270115  0.904892  0.092577  0.098209
# four   0.902877  0.755239  0.754449  0.860750
# five   0.723809  0.051817  0.962294  0.772480
# six    0.598292  0.822128  0.271340  0.776449

# %%
# stacked=True : 1개 인덱스에 대한 각 열의 값을 한줄로 쌓아서 보여줌
df2.plot(kind='barh', stacked=True)

# %%
# 2.3. Histogram 그리기
# histogram은 index가 필요없다.
s3 = pd.Series(np.random.normal(0, 1, size=200))
print(s3)
# bins갯수 : 10개
s3.hist()
# Out:
# 0      1.430880
# 1     -0.806539
# 2      1.149068
# 3     -0.843489
# 4      0.628437
#          ...
# 195    0.072445
# 196    1.461582
# 197    0.846650
# 198   -0.104643
# 199    1.693572
# Length: 200, dtype: float64

# %%
# x 축의 구간 개수를 bin이라 함
# bins=50 : x축의 구간 갯수를 50으로 설정
s3.hist(bins=50)

# %%
# normed=True : 각 bin에 속하는 개수를 전체 개수로 나눈 비율, 
#                즉 정규화 한 값을 bar의 높이로 사용하게 된다.
s3.hist(bins=100, normed=True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:316: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %%
# 2.4. 산점도(Scatter plot) 그리기
# 산점도 : 서로 다른 두 개의 독립변수에 대해 두 변수가 어떤 관계가 있는지 살펴보기 위해 사용
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))
# X : 100*2 array
X = np.concatenate((x1, x2), axis=1)
print(X)
df3 = pd.DataFrame(X, columns=["x1", "x2"])
print(df3)
# Out:
# [[ 1.12091681e+00 -4.06935959e+00]
#  [ 2.61224486e+00 -1.17886886e+00]
#  [-5.62465552e-01  6.66994275e+00]
#  [ 9.73168549e-01 -1.62384652e+00]
#  [ 5.42618980e-01 -3.52086449e+00]
#  [ 8.95527224e-01 -5.64730737e+00]
#  [ 1.10537203e+00  1.84326651e+00]
#  [ 2.79305493e+00 -2.49460240e+00]
#  [ 8.75624233e-01  7.88489347e-01]
#  [ 1.05709572e+00 -7.85757056e-02]
#  [ 7.68668264e-01  2.61959714e+00]
#  [ 1.07454858e+00 -5.90239178e+00]
#  [ 1.21845953e-01 -3.10884309e+00]
#  [ 9.57733140e-01 -2.18232822e+00]
#  [ 1.92884269e-03 -5.82942225e+00]
#  [ 1.63402425e+00 -5.16398489e+00]
#  [ 6.34166451e-01 -4.53754197e+00]
#  [ 1.32696444e+00 -2.04141688e+00]
#  [ 5.27737863e-01 -1.66745677e-01]
#  [ 5.25693778e-01 -1.13592733e+01]
#  [ 1.32276356e+00 -4.84611067e+00]
#  [ 2.02013610e+00 -1.19974857e+00]
#  [ 2.05707221e+00  1.91337842e+00]
#  [ 2.27923692e+00  8.78190383e-01]
#  [ 1.07903074e+00 -7.28868616e+00]
#  [ 2.91603739e-02 -3.25665735e+00]
#  [-7.79235788e-01 -2.99233014e+00]
# ...

# %%
# x1이 x축, x2가 y축
plt.scatter(df3['x1'], df3['x2'])

# %%
# 3. Plot 모양 변형하기

# 비어있는 figure 생성
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# subplot 추가하기, add_subplot 에는 총 3가지 인자가 들어간다.
# 1번째 숫자와 2번째 숫자 : 우리가 figure를 어떤 크기로 나눌지에 대한 값이다. 
# 즉 위의 같은 경우는 2,2 이므로 우리의 figure를 2x2로 나눈다는 뜻.
# 세번째 숫자 : 첫번째, 두번째 숫자로 나눈 figure에서 좌측상단으로 우측방향으로 숫자가 붙는다. 
# 이때 우리가 add하고자 하는 subplot이 몇번째에 들어가는지를 나타낸다.
# 즉, 위와 같은 경우 figure는 다음과 같이 나누어진다.
# 1  2
# 3  4
# 이때 우리는 1위치에 subplot을 추가하고 해당 subplot을 ax1이라는 변수로 반환받는다.
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
# ax1 axes의 content 변경하기
ax1.plot(np.random.randn(50).cumsum())
# axes 객체를 주지 않고 plt.plot()을 실행하면 
# 맨 마지막에 생성된 ax3 axes의 content 생성함
plt.plot(np.random.randn(200).cumsum())
# tight_layout() : subplot의 간격을 적정하게 띄워주게 하는 함수
fig.tight_layout()

# %%
# 그럼 우리가 원하는 위치에 그림을 그리기 위해서는?
# 위에서 add_subplot 을 할때 변수명을 지정하여 반환값을 받았다.
# 해당 변수를 통해 plot을 그리면 된다.
ax1.hist(np.random.randn(100), bins = 20) # bins는 x축 bar의 개수
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
# 3-2. Plot 함수 parameter 설정
# 예제 1
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'mv')
plt.axis([0, 6, 0, 20])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 6, 0, 20]

# %%
# 예제 2
plt.plot(np.random.randn(50), color = 'g', marker='o', linestyle='--')

# %%
# 예제 3
fig, axes = plt.subplots(2,1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
# plot 함수를 그릴때, figure에서 원하는 위치를 지정하기 위해 ax 속성을 사용
# axes[0]인 첫번째 axes에 그리기
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)
# axes[1]인 두번째 axes에 그리기
data.plot(kind='barh', ax=axes[1], color='g', alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 우리가 만들 plot의 눈금, 레이블, 범위 등을 지정 및 수정할 수 있다.
# 예제 4
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 이때 그래프에서 나타내는 눈금을 tick이라고 한다.
# 즉, 위의 그래프의 x tick은 200이고 y tick은 10이다.
ax.set_xticks([0, 250, 500, 750, 1000])

# %%
# 눈금을 문자로 하기 위해서는?
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation = 30, fontsize='small')

# %%
# 제목 입력하기
ax.set_title('random walk plot')
# Out:
# Text(0.5, 1, 'random walk plot')

# %%
# 라벨 입력하기
ax.set_xlabel('Stages')
ax.set_ylabel('Values')
# Out:
# Text(58.902777777777786, 0.5, 'Values')

# %%
# 예제 5
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.plot(np.random.randn(1000).cumsum(), 'k', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'b--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'r.', label='three')

# %%
# 범례 표시하기
ax.legend(loc='best')
# loc는 범례가 위치할 곳을 의미한다. best를 주게 되면 현재 그래프에서 최적의 위치를 자동으로 찾는다.

# %%
# 현재 그래프의 x축 범위를 가져온다.
# ax.get_xlim()
# x축 범위 및 y축 범위 수정하기
ax.set_xlim([100,900])
ax.set_ylim([-100,100])
# Out:
# (-100, 100)

# %%
# 예제 6
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
#  c : color, s : size
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'entry b')

# %%
# 예제 7
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131) # == plt.subplot(1,3,1)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
# 예제 8
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
# Out:
# <img src="data:image/png;base64,..." width="640">
